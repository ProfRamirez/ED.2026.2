# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfRamirez/ED.2026.2/blob/main/ListaEncadeadaDupla_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
UFRJ - Universidade Federal do Rio de Janeiro
CCMN - Centro de Ciência Matemáticas e da Natureza
IM   - Instituto de Matemática

Disciplina: Estrutura de Dados (MAE014 - ED.2026.2)
Prof.     : Milton R Ramirez (milton@matematica.ufrj.br)

Data Criação  : 24 de setembro de 2026
Data Alteração: 24 de setembro de 2026

Exemplos de implementação de Lista Encadeada DUPLA em Python
"""

# CLasse No da Lista encadeada DUPLA
class NoDaLista:
  def __init__(self, dado) -> None:
    self.dado = dado
    self.prox = None
    self.ant = None

# Classe Lista encadeada DUPLA
class ListaEncadeadaDupla:
  def __init__(self) -> None:
    self.inicio = None
    self.fim = None

  def insereNoInicio(self, dado) -> None:
    novoNo = NoDaLista(dado)
    if self.inicio is None:
      self.inicio = novoNo
      self.fim = novoNo
    else:
      novoNo.prox = self.inicio
      self.inicio.ant = novoNo
      self.inicio = novoNo

  """ O exercico aqui e implementar as mesmas funções
  que feitas para a lista simples com a devidas adaptações,
  tanto na logica da função, como da
